# %% [markdown]
# Cell 1 — Install packages

# %%
# Install required packages (run once)
# %pip install -q mne PyWavelets scikit-learn seaborn imbalanced-learn
# %pip install -q azureml-core azure-ai-ml azure-identity

print("✅ Packages installed (if no errors above).")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ✅ Packages installed (if no errors above).

# %% [markdown]
# Cell 2 — Load libraries + set seeds

# %%
# Basic utilities
import os
import random
import pickle

# Arrays
import numpy as np

# EEG processing
import mne
import pywt

# ML tools
from sklearn.decomposition import FastICA
from sklearn.metrics import confusion_matrix, roc_auc_score

# Balancing
from imblearn.over_sampling import SMOTE, RandomOverSampler

# Helpers
from typing import Optional, Union, Sequence, Dict, Tuple, List

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# TensorFlow / Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger

try:
    tf.keras.utils.enable_interactive_logging()
except Exception:
    pass

# Set seeds
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

print("✅ Imports done + seeds set.")
# Out:
# 2026-01-30 04:05:50.515048: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-30 04:05:50.532138: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769745950.551705   10767 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769745950.557572   10767 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769745950.572605   10767 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769745950.572624   10767 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769745950.572626   10767 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769745950.572627   10767 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-30 04:05:50.577548: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✅ Imports done + seeds set.

# %% [markdown]
# Cell 3 — Azure download + load AD arrays + build labels (EXCLUDING last 5)

# %%
import os
import numpy as np
from azureml.core import Workspace, Dataset

print("[STEP 1] Connecting to Azure ML workspace...")

subscription_id = "eccc04ba-d8b0-4f70-864a-b4a6753bfc72"
resource_group  = "somnasnest"
workspace_name  = "SomnasNest"

# RELATIVE path inside workspaceblobstore
folder_path = "UI/2026-01-30_033805_UTC/Data Array/"

ws = Workspace.get(
    name=workspace_name,
    subscription_id=subscription_id,
    resource_group=resource_group
)
print("[STEP 1] Workspace connected ✅")

# IMPORTANT: explicitly get workspaceblobstore
datastore = ws.datastores["workspaceblobstore"]
print("[STEP 1] workspaceblobstore loaded ✅")

# v1-style FileDataset
ds = Dataset.File.from_files(path=(datastore, folder_path))
print("[STEP 1] FileDataset created ✅")

local_dir = "./_parkinson_data_array"
os.makedirs(local_dir, exist_ok=True)

print(f"[STEP 1] Downloading data to: {local_dir} ...")
ds.download(target_path=local_dir, overwrite=True)
print("[STEP 1] Download complete ✅")

# Load NumPy arrays
arrays = {}
print("[STEP 1] Loading .npy files...")
for root, _, files in os.walk(local_dir):
    for f in files:
        if f.lower().endswith(".npy"):
            p = os.path.join(root, f)
            arrays[f] = np.load(p, allow_pickle=False)
            print(f"  Loaded: {f} -> {arrays[f].shape}")

# Sanity check
required = {"parkinson_negative.npy", "parkinson_positive.npy"}
if not required.issubset(arrays):
    raise FileNotFoundError(f"❌ Missing files: {required - arrays.keys()}")

X_neg_full = arrays["parkinson_negative.npy"].astype(np.float32)
X_pos_full = arrays["parkinson_positive.npy"].astype(np.float32)

print("✅ Arrays loaded:")
print("  parkinson_negative.npy (full):", X_neg_full.shape)
print("  parkinson_positive.npy (full):", X_pos_full.shape)

# Drop last 5 trials
X_neg = X_neg_full[:-5]
X_pos = X_pos_full[:-5]

print("✅ After removing last 5 trials:")
print("  parkinson_negative.npy:", X_neg.shape)
print("  parkinson_positive.npy:", X_pos.shape)

# Labels
y_neg = np.zeros(X_neg.shape[0], dtype=np.int32)
y_pos = np.ones(X_pos.shape[0], dtype=np.int32)
# Out:
# [STEP 1] Connecting to Azure ML workspace...
# [STEP 1] Workspace connected ✅
# [STEP 1] workspaceblobstore loaded ✅
# [STEP 1] FileDataset created ✅
# [STEP 1] Downloading data to: ./_parkinson_data_array ...
# {'infer_column_types': 'False', 'activity': 'download'}
# {'infer_column_types': 'False', 'activity': 'download', 'activityApp': 'FileDataset'}
# [STEP 1] Download complete ✅
# [STEP 1] Loading .npy files...
#   Loaded: parkinson_negative.npy -> (31, 62, 120000)
#   Loaded: parkinson_positive.npy -> (21, 62, 60000)
# ✅ Arrays loaded:
#   parkinson_negative.npy (full): (31, 62, 120000)
#   parkinson_positive.npy (full): (21, 62, 60000)
# ✅ After removing last 5 trials:
#   parkinson_negative.npy: (26, 62, 120000)
#   parkinson_positive.npy: (16, 62, 60000)
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented

# %% [markdown]
# * downsample to 500 Hz

# %%
import mne

sfreq_in = 1000
sfreq_out = 500

print("[STEP 2] Downsampling negative class...")

X_neg_ds = mne.filter.resample(
    X_neg.astype(np.float64, copy=False),
    down=sfreq_in // sfreq_out,  # 2
    npad="auto",
    axis=-1,
    verbose=True
).astype(np.float32, copy=False)

print("Negative class:")
print("  Before:", X_neg.shape, X_neg.dtype)
print("  After: ", X_neg_ds.shape, X_neg_ds.dtype)

# Positive class stays unchanged
X_pos_ds = X_pos
# Out:
# [STEP 2] Downsampling negative class...
# Negative class:
#   Before: (26, 62, 120000) float32
#   After:  (26, 62, 60000) float32

# %%
# Combine
X_all_trials = np.concatenate([X_neg_ds, X_pos_ds], axis=0)
y_all_trials = np.concatenate([y_neg, y_pos], axis=0)

print("[STEP 3] Combined dataset:")
print("  X_all_trials:", X_all_trials.shape)
print("  y_all_trials:", y_all_trials.shape)
print("  Class counts:", np.unique(y_all_trials, return_counts=True))

# Required debug prints
print("Before:", X_neg.shape, X_neg.dtype)
print("After: ", X_neg_ds.shape, X_neg_ds.dtype)
# Out:
# [STEP 3] Combined dataset:
#   X_all_trials: (42, 62, 60000)
#   y_all_trials: (42,)
#   Class counts: (array([0, 1], dtype=int32), array([26, 16]))
# Before: (26, 62, 120000) float32
# After:  (26, 62, 60000) float32

# %% [markdown]
# Cell 4 — Helper + leakage-safe preprocessing classes

# %%
def _names_from_index_mapping(n_channels, index_to_name):
    if index_to_name is None:
        return [f"EEG{i+1}" for i in range(n_channels)]
    keys = list(index_to_name.keys())
    is_zero_based = (0 in keys) and (1 not in keys)
    names = []
    for i in range(n_channels):
        key = i if is_zero_based else (i + 1)
        names.append(index_to_name.get(key, f"EEG{i+1}"))
    return names

def _make_raw(eeg, sfreq, ch_names, use_standard_1020=True):
    ch_types = ['eog' if str(n).upper().startswith("EOG") else 'eeg' for n in ch_names]
    info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types=ch_types)
    raw = mne.io.RawArray(eeg.astype(np.float32, copy=False), info, verbose=False)

    montage_applied = False
    if use_standard_1020:
        try:
            mont = mne.channels.make_standard_montage("standard_1020")
            raw.set_montage(mont, match_case=False, on_missing="ignore")
            montage_applied = True
        except Exception:
            montage_applied = False

    return raw, montage_applied

class WaveletICA:
    def __init__(self, wavelet="db4", level=3, n_components=10, random_state=42):
        self.wavelet = wavelet
        self.level = level
        self.n_components = n_components
        self.random_state = random_state
        self.ica_ = None
        self._n_ch = None

    def fit(self, X):
        C = X.shape[0]
        self._n_ch = C
        coeffs = pywt.wavedec(X, wavelet=self.wavelet, level=self.level, axis=1)
        A = coeffs[0]
        k = int(min(self.n_components, C))
        self.ica_ = FastICA(n_components=k, random_state=self.random_state)
        S = self.ica_.fit_transform(A.T)
        A_denoised = self.ica_.inverse_transform(S).T
        coeffs[0] = A_denoised
        _ = pywt.waverec(coeffs, wavelet=self.wavelet, axis=1)
        return self

    def transform(self, X):
        assert self.ica_ is not None, "WaveletICA not fitted yet."
        coeffs = pywt.wavedec(X, wavelet=self.wavelet, level=self.level, axis=1)
        A = coeffs[0]
        S = self.ica_.transform(A.T)
        A_denoised = self.ica_.inverse_transform(S).T
        coeffs[0] = A_denoised
        Y = pywt.waverec(coeffs, wavelet=self.wavelet, axis=1)

        if Y.shape[1] < X.shape[1]:
            Y = np.pad(Y, ((0, 0), (0, X.shape[1] - Y.shape[1])), mode="constant")
        elif Y.shape[1] > X.shape[1]:
            Y = Y[:, :X.shape[1]]

        return Y.astype(np.float32, copy=False)

class EEGPreprocessor:
    def __init__(
        self,
        *,
        index_to_name=None,
        use_standard_1020=True,
        resample_to=None,
        notch_freqs=50.0,
        highpass=0.05,
        bad_point_z=6.0,
        bad_channel_z=5.0,
        interpolate_bad_channels=False,
        car=True,
        use_wica=True,
        wica_components=10,
        wica_wavelet="db4",
        wica_level=3,
        wica_random_state=42
    ):
        self.index_to_name = index_to_name
        self.use_standard_1020 = use_standard_1020
        self.resample_to = resample_to
        self.notch_freqs = notch_freqs
        self.highpass = highpass
        self.bad_point_z = bad_point_z
        self.bad_channel_z = bad_channel_z
        self.interpolate_bad_channels = interpolate_bad_channels
        self.car = car
        self.use_wica = use_wica

        self._sfreq_out = None
        self._train_mu = None
        self._train_sd = None

        self._wica = WaveletICA(
            wavelet=wica_wavelet,
            level=wica_level,
            n_components=wica_components,
            random_state=wica_random_state
        )

    @property
    def sfreq_out(self):
        assert self._sfreq_out is not None, "Preprocessor not run yet."
        return float(self._sfreq_out)

    def _filter_and_reference(self, raw):
        if self.resample_to is not None and float(self.resample_to) != float(raw.info["sfreq"]):
            raw.resample(self.resample_to, npad="auto")
        self._sfreq_out = float(raw.info["sfreq"])

        if self.notch_freqs is not None:
            raw.notch_filter(freqs=self.notch_freqs, verbose=False)

        if self.highpass is not None:
            raw.filter(l_freq=self.highpass, h_freq=None, verbose=False)

        if self.car:
            raw.set_eeg_reference("average", projection=True)
            raw.apply_proj()

    def _repair_transients_with_train_stats(self, raw):
        X = raw.get_data()
        mu = self._train_mu
        sd = self._train_sd
        assert mu is not None and sd is not None, "Training stats not set."

        hi = mu + self.bad_point_z * sd
        lo = mu - self.bad_point_z * sd
        mask = (X > hi) | (X < lo)

        if np.any(mask):
            X_fixed = X.copy()
            t = np.arange(X.shape[1], dtype=float)
            for ch in range(X.shape[0]):
                m = mask[ch]
                if m.any():
                    good = ~m
                    if good.sum() >= 2:
                        X_fixed[ch, m] = np.interp(t[m], t[good], X_fixed[ch, good])
            raw._data = X_fixed

    def fit(self, X_train, sfreq):
        C = X_train.shape[0]
        ch_names = _names_from_index_mapping(C, self.index_to_name)

        raw_train, _ = _make_raw(X_train, sfreq, ch_names, self.use_standard_1020)
        self._filter_and_reference(raw_train)

        Xt = raw_train.get_data()
        self._train_mu = Xt.mean(axis=1, keepdims=True)
        self._train_sd = Xt.std(axis=1, keepdims=True) + 1e-12

        if self.use_wica:
            self._wica.fit(Xt)

        return self

    def transform(self, X, sfreq):
        C = X.shape[0]
        ch_names = _names_from_index_mapping(C, self.index_to_name)

        raw, _ = _make_raw(X, sfreq, ch_names, self.use_standard_1020)
        self._filter_and_reference(raw)
        self._repair_transients_with_train_stats(raw)

        Xf = raw.get_data()
        if self.use_wica:
            Xf = self._wica.transform(Xf)

        return Xf.astype(np.float32, copy=False), self.sfreq_out

    def fit_transform(self, X_train, sfreq):
        self.fit(X_train, sfreq)
        X_clean, fs_out = self.transform(X_train, sfreq)
        return X_clean, fs_out

print("✅ Preprocessing classes loaded.")
# Out:
# ✅ Preprocessing classes loaded.

# %% [markdown]
# Cell 5 — Set sampling frequency + Preprocess all trials

# %%
print("[STEP 2] Starting preprocessing...")

fs = 500.0  # <-- CHANGE if needed
print(f"[STEP 2] Using fs={fs} Hz")

CHANNEL_MAP = None

pre = EEGPreprocessor(
    index_to_name=CHANNEL_MAP,
    use_standard_1020=True,
    resample_to=None,
    notch_freqs=[50.0, 100.0, 150.0],
    highpass=0.05,
    bad_point_z=6.0,
    bad_channel_z=5.0,
    interpolate_bad_channels=False,
    car=True,
    use_wica=True,
    wica_components=10,
    wica_wavelet="db4",
    wica_level=3,
    wica_random_state=42
)

max_calib_trials = min(10, X_all_trials.shape[0])
print(f"[STEP 2] Fitting preprocessor on first {max_calib_trials} trials...")

calib_trials = X_all_trials[:max_calib_trials]
X_calib = np.concatenate(calib_trials, axis=1).astype(np.float32, copy=False)

X_calib_clean, fs_out = pre.fit_transform(X_calib, fs)
print(f"[STEP 2] Preprocessor fitted ✅ | fs_out={fs_out} Hz")

data_clean = []
for i in range(X_all_trials.shape[0]):
    X_clean, _ = pre.transform(X_all_trials[i], fs)
    data_clean.append(X_clean.astype(np.float32, copy=False))
    if (i + 1) % 5 == 0 or (i + 1) == X_all_trials.shape[0]:
        print(f"[STEP 2] Preprocessed {i+1}/{X_all_trials.shape[0]} trials...")

data_clean = np.array(data_clean, dtype=np.float32)

print("[STEP 2] Done preprocessing ✅")
print("  data_clean shape:", data_clean.shape)
print("  labels shape    :", y_all_trials.shape)
print("  class counts    :", np.unique(y_all_trials, return_counts=True))
# Out:
# [STEP 2] Starting preprocessing...
# [STEP 2] Using fs=500.0 Hz
# [STEP 2] Fitting preprocessor on first 10 trials...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [STEP 2] Preprocessor fitted ✅ | fs_out=500.0 Hz
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [STEP 2] Preprocessed 5/42 trials...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [STEP 2] Preprocessed 10/42 trials...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [STEP 2] Preprocessed 15/42 trials...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [STEP 2] Preprocessed 20/42 trials...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [STEP 2] Preprocessed 25/42 trials...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [STEP 2] Preprocessed 30/42 trials...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [STEP 2] Preprocessed 35/42 trials...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [STEP 2] Preprocessed 40/42 trials...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# [STEP 2] Preprocessed 42/42 trials...
# [STEP 2] Done preprocessing ✅
#   data_clean shape: (42, 62, 60000)
#   labels shape    : (42,)
#   class counts    : (array([0, 1], dtype=int32), array([26, 16]))

# %% [markdown]
# Cell 6 — Augmentation

# %%
print("[STEP 3] Starting augmentation (segmentation)...")

def augment_data(trial_data, label, segment_size=100):
    segments = []
    labels = []
    n_segments = trial_data.shape[1] // segment_size
    for i in range(n_segments):
        seg = trial_data[:, i*segment_size:(i+1)*segment_size]
        segments.append(seg.astype(np.float32, copy=False))
        labels.append(int(label))
    return segments, labels

augmented = []
aug_targets = []

for idx, (trial, y) in enumerate(zip(data_clean, y_all_trials), start=1):
    segs, ys = augment_data(trial, y, segment_size=100)
    augmented.extend(segs)
    aug_targets.extend(ys)
    if idx % 5 == 0 or idx == len(data_clean):
        print(f"[STEP 3] Segmented {idx}/{len(data_clean)} trials...")

augmented = np.array(augmented, dtype=np.float32)   # (N,127,100)
aug_targets = np.array(aug_targets, dtype=np.int32)

print("[STEP 3] Augmentation done ✅")
print("  augmented shape:", augmented.shape)
print("  aug_targets shape:", aug_targets.shape)
print("  class counts:", np.unique(aug_targets, return_counts=True))
# Out:
# [STEP 3] Starting augmentation (segmentation)...
# [STEP 3] Segmented 5/42 trials...
# [STEP 3] Segmented 10/42 trials...
# [STEP 3] Segmented 15/42 trials...
# [STEP 3] Segmented 20/42 trials...
# [STEP 3] Segmented 25/42 trials...
# [STEP 3] Segmented 30/42 trials...
# [STEP 3] Segmented 35/42 trials...
# [STEP 3] Segmented 40/42 trials...
# [STEP 3] Segmented 42/42 trials...
# [STEP 3] Augmentation done ✅
#   augmented shape: (25200, 62, 100)
#   aug_targets shape: (25200,)
#   class counts: (array([0, 1], dtype=int32), array([15600,  9600]))

# %% [markdown]
# Cell 7 — “Fair selection”

# %%
'''print("[STEP 4] Fair selection step...")

class_data = {0: [], 1: []}
for x, y in zip(augmented, aug_targets):
    class_data[int(y)].append(x)

max_per_class = 20000

selected_data = []
selected_targets = []

for cls in [0, 1]:
    picked = class_data[cls][:max_per_class]
    selected_data.extend(picked)
    selected_targets.extend([cls] * len(picked))
    print(f"[STEP 4] Picked {len(picked)} samples for class {cls}")

selected_data = np.array(selected_data, dtype=np.float32)   # (N,C,T)
selected_targets = np.array(selected_targets, dtype=np.int32)

print("[STEP 4] Selection done ✅")
print("  selected_data shape:", selected_data.shape)
print("  selected_targets shape:", selected_targets.shape)
print("  class counts:", np.unique(selected_targets, return_counts=True))
'''

# %%
selected_data = augmented
selected_targets = aug_targets

# %% [markdown]
# Cell 8 — Reshape for EEGNet input

# %%
print("[STEP 5] Reshaping data for EEGNet...")

X_all = selected_data[..., np.newaxis].astype(np.float32, copy=False)  # (N,C,T,1)
y_all = selected_targets.astype(np.int32, copy=False)

print("[STEP 5] Done ✅")
print("  X_all shape:", X_all.shape)
print("  y_all shape:", y_all.shape)
print("  class counts:", np.unique(y_all, return_counts=True))
# Out:
# [STEP 5] Reshaping data for EEGNet...
# [STEP 5] Done ✅
#   X_all shape: (25200, 62, 100, 1)
#   y_all shape: (25200,)
#   class counts: (array([0, 1], dtype=int32), array([15600,  9600]))

# %% [markdown]
# Cell 9 — Train-only normalization on FULL DATA + save mean/std as PKL

# %%
print("[STEP 6] Computing normalization stats on FULL training data (final model)...")

eps = 1e-6
train_mean = np.mean(X_all, axis=(0, 2, 3), keepdims=True).astype(np.float32)
train_std  = np.std(X_all,  axis=(0, 2, 3), keepdims=True).astype(np.float32)
train_std  = np.maximum(train_std, eps)

X_norm = (X_all - train_mean) / train_std

print("[STEP 6] Normalization complete ✅")
print("  train_mean shape:", train_mean.shape)
print("  train_std  shape:", train_std.shape)
print("  X_norm shape     :", X_norm.shape)

# ✅ Modification #3: save mean/std as pkl files
with open("p_train_mean.pkl", "wb") as f:
    pickle.dump(train_mean, f)

with open("p_train_std.pkl", "wb") as f:
    pickle.dump(train_std, f)

print("✅ Saved normalization stats:")
print("  - train_mean.pkl")
print("  - train_std.pkl")
# Out:
# [STEP 6] Computing normalization stats on FULL training data (final model)...
# [STEP 6] Normalization complete ✅
#   train_mean shape: (1, 62, 1, 1)
#   train_std  shape: (1, 62, 1, 1)
#   X_norm shape     : (25200, 62, 100, 1)
# ✅ Saved normalization stats:
#   - train_mean.pkl
#   - train_std.pkl

# %% [markdown]
# Cell 10 — Class balancing using SMOTE

# %%
print("[STEP 7] Applying SMOTE on FULL normalized training data (separate step)...")

input_shape = X_norm.shape[1:]  # (C,T,1)
X_2d = X_norm.reshape(X_norm.shape[0], -1)

unique_before, counts_before = np.unique(y_all, return_counts=True)
minority_n = int(np.min(counts_before))

print("[STEP 7] Class counts before SMOTE:", dict(zip(unique_before, counts_before)))

if minority_n >= 2:
    k_neighbors = max(1, min(5, minority_n - 1))
    smote = SMOTE(random_state=42, k_neighbors=k_neighbors)
    X_bal_2d, y_bal = smote.fit_resample(X_2d, y_all)
    print(f"[STEP 7] SMOTE applied ✅ (k={k_neighbors})")
else:
    ros = RandomOverSampler(random_state=42)
    X_bal_2d, y_bal = ros.fit_resample(X_2d, y_all)
    print("[STEP 7] SMOTE not possible → used RandomOverSampler ⚠️")

X_bal = X_bal_2d.reshape(-1, *input_shape).astype(np.float32)
y_bal = y_bal.astype(np.float32)

unique_after, counts_after = np.unique(y_bal.astype(int), return_counts=True)
print("[STEP 7] Balanced shapes:")
print("  X_bal:", X_bal.shape)
print("  y_bal:", y_bal.shape)
print("[STEP 7] Class counts after balancing:", dict(zip(unique_after, counts_after)))
# Out:
# [STEP 7] Applying SMOTE on FULL normalized training data (separate step)...
# [STEP 7] Class counts before SMOTE: {np.int32(0): np.int64(15600), np.int32(1): np.int64(9600)}
# [STEP 7] SMOTE applied ✅ (k=5)
# [STEP 7] Balanced shapes:
#   X_bal: (31200, 62, 100, 1)
#   y_bal: (31200,)
# [STEP 7] Class counts after balancing: {np.int64(0): np.int64(15600), np.int64(1): np.int64(15600)}

# %% [markdown]
# Cell 11 — EEGNet model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import (
    Input, SeparableConv2D, DepthwiseConv2D, BatchNormalization, Activation,
    AveragePooling2D, Dropout, Dense, Add, Lambda, Reshape,
    LayerNormalization, MultiHeadAttention, GlobalAveragePooling1D
)
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

def SpatialAttention(x):
    """Spatial attention over EEG electrodes (channel dimension)."""
    attention = tf.keras.layers.GlobalAveragePooling2D()(x)          # (batch, channels)
    attention = Dense(64, activation='relu')(attention)
    attention = Dense(x.shape[1], activation='sigmoid')(attention)   # (batch, channels)
    # ✅ fix: use a Keras layer (not tf.reshape) so it works with KerasTensors
    attention = Reshape((x.shape[1], 1, 1))(attention)               # (batch, channels, 1, 1)
    return tf.keras.layers.Multiply()([x, attention])

def TransformerBlock(x, num_heads=4, key_dim=64, ff_dim=128, dropout_rate=0.1):
    """Transformer block with MHSA + FFN."""
    attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(x, x)
    attn_output = Dropout(dropout_rate)(attn_output)
    attn_output = Add()([x, attn_output])
    attn_output = LayerNormalization()(attn_output)

    ff_output = Dense(ff_dim, activation='relu')(attn_output)
    ff_output = Dropout(dropout_rate)(ff_output)
    ff_output = Dense(x.shape[-1])(ff_output)
    x = Add()([attn_output, ff_output])
    x = LayerNormalization()(x)
    return x

def EEGNet_SpatialTransformer(input_shape=(127, 100, 1), dropout_rate=0.5, num_heads=4, ff_dim=128):
    inputs = Input(shape=input_shape)

    # Depthwise Separable Convolution with Shared Filters
    x = SeparableConv2D(32, (1, 5), padding='same', use_bias=False)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Spatial Attention Mechanism
    x = SpatialAttention(x)

    # Depthwise Convolution (Spatial Filtering per EEG Channel)
    # ✅ keep architecture same, but make electrode count match input_shape[0]
    x = DepthwiseConv2D((input_shape[0], 1), use_bias=False, depth_multiplier=2, padding='valid')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Residual Connection (Skip Connection) — keep as you wrote, but adapt to input channels
    residual = Lambda(lambda y: y[:, :, :, :32])(inputs)
    residual = BatchNormalization()(residual)
    x = Add()([x, residual])
    x = BatchNormalization()(x)

    # First Average Pooling Layer
    x = AveragePooling2D((1, 4))(x)
    x = Dropout(dropout_rate)(x)

    # Depthwise Separable Convolution (Extract Temporal-Spatial Features)
    x = SeparableConv2D(64, (1, 3), padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Second Average Pooling Layer
    x = AveragePooling2D((1, 4))(x)
    x = Dropout(dropout_rate)(x)

    # Transformer Block (Long-Term Dependencies)
    x_shape = K.int_shape(x)
    x = Reshape((x_shape[1], x_shape[2] * x_shape[3]))(x)
    x = TransformerBlock(x, num_heads=num_heads, key_dim=64, ff_dim=ff_dim, dropout_rate=0.1)

    # Global Average Pooling
    x = GlobalAveragePooling1D()(x)
    x = BatchNormalization()(x)

    # Fully Connected Layers
    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)

    outputs = Dense(1, activation='sigmoid')(x)

    model = Model(inputs, outputs, name="EEGNet_SpatialTransformer")
    return model

# Instantiate + compile
model = EEGNet_SpatialTransformer(input_shape=(127, 100, 1))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=[tf.keras.metrics.BinaryAccuracy(name='accuracy', threshold=0.5)]
)
# Out:
# 2026-01-30 04:13:24.534580: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %% [markdown]
# Cell 12 — Train FINAL generalized model

# %%
# Cell 12 — Train FINAL generalized model (with 80/20 train/val split + val_loss early stopping + plots)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, CSVLogger

print("[STEP 8] Preparing train/validation split (80/20)...")

# ✅ 80/20 split with stratification to preserve class balance in val set
X_train, X_val, y_train, y_val = train_test_split(
    X_bal, y_bal,
    test_size=0.20,
    random_state=42,
    stratify=y_bal.astype(int)
)

print("[STEP 8] Split complete ✅")
print("  X_train:", X_train.shape, " y_train:", y_train.shape)
print("  X_val  :", X_val.shape,   " y_val  :", y_val.shape)

# Track class distribution in each split
u_tr, c_tr = np.unique(y_train.astype(int), return_counts=True)
u_va, c_va = np.unique(y_val.astype(int), return_counts=True)
print("[STEP 8] Class counts (train):", dict(zip(u_tr, c_tr)))
print("[STEP 8] Class counts (val)  :", dict(zip(u_va, c_va)))

print("[STEP 8] Building EEGNet_SpatialTransformer model...")
model = EEGNet_SpatialTransformer(input_shape=X_train.shape[1:], dropout_rate=0.5, num_heads=4, ff_dim=128)

# compile exactly as before (binary)
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=[keras.metrics.BinaryAccuracy(name="accuracy", threshold=0.5)]
)

print("[STEP 8] Model built ✅")
model.summary()

print("[STEP 8] Setting callbacks (monitoring val_loss)...")

# ✅ Early stopping based on validation loss
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# ✅ LR scheduler based on validation loss
lr_plateau = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

csv_logger = CSVLogger("ad_final_train_log.csv", append=False)
callbacks = [early_stop, lr_plateau, csv_logger]

print("[STEP 8] Starting training on TRAIN set + validating on VAL set...")
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=200,
    batch_size=16,
    shuffle=True,
    verbose=1,
    callbacks=callbacks
)

print("[STEP 8] Training complete ✅")

# ✅ Save final model
final_model_path = "p_eegformer-v1.keras"
model.save(final_model_path)

print("✅ Final model saved:", final_model_path)
print("✅ Training log saved: ad_final_train_log.csv")
print("✅ Normalization files saved: train_mean.pkl, train_std.pkl")

# -----------------------------
# Plot metrics per epoch
# -----------------------------
print("[STEP 9] Plotting training curves...")

hist = history.history
epochs_ran = range(1, len(hist["loss"]) + 1)

# Loss plot
plt.figure()
plt.plot(epochs_ran, hist["loss"], label="loss")
plt.plot(epochs_ran, hist["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Val Loss")
plt.legend()
plt.grid(True)
plt.show()

# Accuracy plot (handle key name safely)
acc_key = "accuracy" if "accuracy" in hist else "binary_accuracy"
val_acc_key = "val_accuracy" if "val_accuracy" in hist else "val_binary_accuracy"

plt.figure()
plt.plot(epochs_ran, hist[acc_key], label=acc_key)
plt.plot(epochs_ran, hist[val_acc_key], label=val_acc_key)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Val Accuracy")
plt.legend()
plt.grid(True)
plt.show()

print("[STEP 9] Plots generated ✅")
# Out:
# [STEP 8] Preparing train/validation split (80/20)...
# [STEP 8] Split complete ✅
#   X_train: (24960, 62, 100, 1)  y_train: (24960,)
#   X_val  : (6240, 62, 100, 1)  y_val  : (6240,)
# [STEP 8] Class counts (train): {np.int64(0): np.int64(12480), np.int64(1): np.int64(12480)}
# [STEP 8] Class counts (val)  : {np.int64(0): np.int64(3120), np.int64(1): np.int64(3120)}
# [STEP 8] Building EEGNet_SpatialTransformer model...
# [STEP 8] Model built ✅
# Model: "EEGNet_SpatialTransformer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 62, 100,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 62, 100,   │         37 │ input_layer_1[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 62, 100,   │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 62, 100,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ activation_3[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 64)        │      2,112 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 62)        │      4,030 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 62, 1, 1)  │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 62, 100,   │          0 │ activation_3[0][… │
# │ (Multiply)          │ 32)               │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 1, 100,    │      3,968 │ multiply_1[0][0]  │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 100,    │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 62, 100,   │          0 │ input_layer_1[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 1, 100,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 62, 100,   │          4 │ lambda_1[0][0]    │
# │ (BatchNormalizatio… │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 62, 100,   │          0 │ activation_4[0][… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 62, 100,   │        256 │ add_3[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_2 │ (None, 62, 25,    │          0 │ batch_normalizat… │
# │ (AveragePooling2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 62, 25,    │          0 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 62, 25,    │      4,288 │ dropout_6[0][0]   │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 62, 25,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 62, 25,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_3 │ (None, 62, 6, 64) │          0 │ activation_5[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 62, 6, 64) │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 62, 384)   │          0 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 62, 384)   │    394,368 │ reshape_3[0][0],  │
# │ (MultiHeadAttentio… │                   │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 62, 384)   │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 62, 384)   │          0 │ reshape_3[0][0],  │
# │                     │                   │            │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 62, 384)   │        768 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 62, 128)   │     49,280 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 62, 128)   │          0 │ dense_8[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 62, 384)   │     49,536 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 62, 384)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 62, 384)   │        768 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 384)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 384)       │      1,536 │ global_average_p… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 128)       │     49,280 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 1)         │        129 │ dropout_11[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 561,512 (2.14 MB)
#  Trainable params: 560,038 (2.14 MB)
#  Non-trainable params: 1,474 (5.76 KB)
# [STEP 8] Setting callbacks (monitoring val_loss)...
# [STEP 8] Starting training on TRAIN set + validating on VAL set...
# Epoch 1/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 258s 162ms/step - accuracy: 0.8348 - loss: 0.3833 - val_accuracy: 0.9979 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 2/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 252s 161ms/step - accuracy: 0.9850 - loss: 0.0410 - val_accuracy: 0.9937 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 3/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 251s 161ms/step - accuracy: 0.9891 - loss: 0.0349 - val_accuracy: 0.9995 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 4/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 251s 161ms/step - accuracy: 0.9940 - loss: 0.0171 - val_accuracy: 0.9998 - val_loss: 4.6387e-04 - learning_rate: 0.0010
# Epoch 5/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 250s 160ms/step - accuracy: 0.9968 - loss: 0.0103 - val_accuracy: 0.9986 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 6/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 249s 160ms/step - accuracy: 0.9973 - loss: 0.0114 - val_accuracy: 0.9998 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 7/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 251s 161ms/step - accuracy: 0.9949 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 2.5503e-04 - learning_rate: 0.0010
# Epoch 8/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 249s 160ms/step - accuracy: 0.9977 - loss: 0.0082 - val_accuracy: 0.9997 - val_loss: 9.8491e-04 - learning_rate: 0.0010
# Epoch 9/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 248s 159ms/step - accuracy: 0.9986 - loss: 0.0045 - val_accuracy: 0.9990 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 10/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 251s 161ms/step - accuracy: 0.9975 - loss: 0.0093 - val_accuracy: 0.9990 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 11/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 249s 160ms/step - accuracy: 0.9987 - loss: 0.0044 - val_accuracy: 0.9998 - val_loss: 3.3451e-04 - learning_rate: 0.0010
# Epoch 12/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 250s 160ms/step - accuracy: 0.9978 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 4.1318e-05 - learning_rate: 0.0010
# Epoch 13/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 251s 161ms/step - accuracy: 0.9986 - loss: 0.0047 - val_accuracy: 0.9950 - val_loss: 0.0158 - learning_rate: 0.0010
# Epoch 14/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 251s 161ms/step - accuracy: 0.9984 - loss: 0.0062 - val_accuracy: 0.9998 - val_loss: 5.4478e-04 - learning_rate: 0.0010
# Epoch 15/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 250s 160ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 1.4240e-04 - learning_rate: 0.0010
# Epoch 16/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 250s 160ms/step - accuracy: 0.9975 - loss: 0.0080 - val_accuracy: 0.9995 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 17/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9976 - loss: 0.0086
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 249s 160ms/step - accuracy: 0.9976 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 1.0119e-04 - learning_rate: 0.0010
# Epoch 18/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 249s 159ms/step - accuracy: 0.9998 - loss: 6.0907e-04 - val_accuracy: 0.9981 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 19/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 250s 160ms/step - accuracy: 1.0000 - loss: 2.6964e-04 - val_accuracy: 1.0000 - val_loss: 4.4648e-05 - learning_rate: 5.0000e-04
# Epoch 20/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 250s 160ms/step - accuracy: 0.9998 - loss: 6.0018e-04 - val_accuracy: 1.0000 - val_loss: 1.1764e-05 - learning_rate: 5.0000e-04
# Epoch 21/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 253s 162ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 1.6754e-05 - learning_rate: 5.0000e-04
# Epoch 22/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 8.4316e-05
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 253s 162ms/step - accuracy: 1.0000 - loss: 8.4469e-05 - val_accuracy: 1.0000 - val_loss: 1.0513e-04 - learning_rate: 5.0000e-04
# Epoch 23/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 252s 162ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 1.7816e-05 - learning_rate: 2.5000e-04
# Epoch 24/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 251s 161ms/step - accuracy: 0.9999 - loss: 2.0756e-04 - val_accuracy: 1.0000 - val_loss: 9.2651e-06 - learning_rate: 2.5000e-04
# Epoch 25/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 248s 159ms/step - accuracy: 1.0000 - loss: 7.6532e-05 - val_accuracy: 1.0000 - val_loss: 1.2643e-05 - learning_rate: 2.5000e-04
# Epoch 26/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 249s 160ms/step - accuracy: 1.0000 - loss: 3.2745e-05 - val_accuracy: 1.0000 - val_loss: 1.6246e-05 - learning_rate: 2.5000e-04
# Epoch 27/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9999 - loss: 4.1876e-04
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 251s 161ms/step - accuracy: 0.9999 - loss: 4.1879e-04 - val_accuracy: 0.9998 - val_loss: 1.9693e-04 - learning_rate: 2.5000e-04
# Epoch 28/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 262s 168ms/step - accuracy: 1.0000 - loss: 1.3247e-05 - val_accuracy: 0.9998 - val_loss: 2.1883e-04 - learning_rate: 1.2500e-04
# Epoch 29/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 253s 162ms/step - accuracy: 1.0000 - loss: 1.1546e-05 - val_accuracy: 1.0000 - val_loss: 3.5079e-05 - learning_rate: 1.2500e-04
# Epoch 30/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 252s 161ms/step - accuracy: 1.0000 - loss: 2.6766e-05 - val_accuracy: 1.0000 - val_loss: 7.1294e-05 - learning_rate: 1.2500e-04
# Epoch 31/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 253s 162ms/step - accuracy: 1.0000 - loss: 2.9896e-04 - val_accuracy: 1.0000 - val_loss: 1.0611e-05 - learning_rate: 1.2500e-04
# Epoch 32/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9999 - loss: 1.8751e-04
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 272s 174ms/step - accuracy: 0.9999 - loss: 1.8759e-04 - val_accuracy: 1.0000 - val_loss: 1.1307e-05 - learning_rate: 1.2500e-04
# Epoch 33/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 286s 183ms/step - accuracy: 1.0000 - loss: 1.0508e-05 - val_accuracy: 1.0000 - val_loss: 9.0349e-06 - learning_rate: 6.2500e-05
# Epoch 34/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 284s 182ms/step - accuracy: 1.0000 - loss: 1.3126e-05 - val_accuracy: 1.0000 - val_loss: 5.1264e-06 - learning_rate: 6.2500e-05
# Epoch 35/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 280s 180ms/step - accuracy: 1.0000 - loss: 2.3726e-06 - val_accuracy: 1.0000 - val_loss: 4.6240e-06 - learning_rate: 6.2500e-05
# Epoch 36/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 287s 184ms/step - accuracy: 1.0000 - loss: 3.9647e-06 - val_accuracy: 1.0000 - val_loss: 3.6215e-06 - learning_rate: 6.2500e-05
# Epoch 37/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 1.0000 - loss: 1.6804e-06
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 318s 181ms/step - accuracy: 1.0000 - loss: 1.6809e-06 - val_accuracy: 1.0000 - val_loss: 3.9662e-06 - learning_rate: 6.2500e-05
# Epoch 38/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 285s 182ms/step - accuracy: 1.0000 - loss: 1.7741e-06 - val_accuracy: 1.0000 - val_loss: 3.6751e-06 - learning_rate: 3.1250e-05
# Epoch 39/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 285s 182ms/step - accuracy: 1.0000 - loss: 8.4926e-07 - val_accuracy: 1.0000 - val_loss: 4.0707e-06 - learning_rate: 3.1250e-05
# Epoch 40/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 296s 190ms/step - accuracy: 1.0000 - loss: 1.1905e-06 - val_accuracy: 1.0000 - val_loss: 4.5027e-06 - learning_rate: 3.1250e-05
# Epoch 41/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 285s 183ms/step - accuracy: 1.0000 - loss: 5.1753e-07 - val_accuracy: 1.0000 - val_loss: 2.9256e-06 - learning_rate: 3.1250e-05
# Epoch 42/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 4.8074e-07
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 288s 185ms/step - accuracy: 1.0000 - loss: 4.8084e-07 - val_accuracy: 1.0000 - val_loss: 2.6891e-06 - learning_rate: 3.1250e-05
# Epoch 43/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 278s 178ms/step - accuracy: 1.0000 - loss: 2.6395e-06 - val_accuracy: 1.0000 - val_loss: 2.4659e-06 - learning_rate: 1.5625e-05
# Epoch 44/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 339s 189ms/step - accuracy: 1.0000 - loss: 6.4368e-07 - val_accuracy: 1.0000 - val_loss: 1.7301e-06 - learning_rate: 1.5625e-05
# Epoch 45/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 300s 193ms/step - accuracy: 1.0000 - loss: 1.7350e-06 - val_accuracy: 1.0000 - val_loss: 1.9903e-06 - learning_rate: 1.5625e-05
# Epoch 46/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 324s 194ms/step - accuracy: 1.0000 - loss: 3.4053e-06 - val_accuracy: 1.0000 - val_loss: 6.3116e-06 - learning_rate: 1.5625e-05
# Epoch 47/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 1.0000 - loss: 7.4711e-06
# Epoch 47: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 302s 193ms/step - accuracy: 1.0000 - loss: 7.4692e-06 - val_accuracy: 1.0000 - val_loss: 2.3075e-06 - learning_rate: 1.5625e-05
# Epoch 48/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 311s 199ms/step - accuracy: 1.0000 - loss: 9.5812e-07 - val_accuracy: 1.0000 - val_loss: 1.8317e-06 - learning_rate: 7.8125e-06
# Epoch 49/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 302s 194ms/step - accuracy: 1.0000 - loss: 3.9032e-07 - val_accuracy: 1.0000 - val_loss: 2.0800e-06 - learning_rate: 7.8125e-06
# Epoch 50/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 298s 191ms/step - accuracy: 1.0000 - loss: 1.3228e-06 - val_accuracy: 1.0000 - val_loss: 2.0835e-06 - learning_rate: 7.8125e-06
# Epoch 51/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 319s 190ms/step - accuracy: 1.0000 - loss: 1.2686e-06 - val_accuracy: 1.0000 - val_loss: 1.4243e-06 - learning_rate: 7.8125e-06
# Epoch 52/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 1.0000 - loss: 4.6015e-07
# Epoch 52: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 299s 191ms/step - accuracy: 1.0000 - loss: 4.6017e-07 - val_accuracy: 1.0000 - val_loss: 1.3246e-06 - learning_rate: 7.8125e-06
# Epoch 53/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 298s 191ms/step - accuracy: 1.0000 - loss: 1.7477e-07 - val_accuracy: 1.0000 - val_loss: 1.3815e-06 - learning_rate: 3.9063e-06
# Epoch 54/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 324s 192ms/step - accuracy: 1.0000 - loss: 1.5500e-06 - val_accuracy: 1.0000 - val_loss: 1.4184e-06 - learning_rate: 3.9063e-06
# Epoch 55/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 298s 191ms/step - accuracy: 1.0000 - loss: 4.5322e-07 - val_accuracy: 1.0000 - val_loss: 1.4097e-06 - learning_rate: 3.9063e-06
# Epoch 56/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 298s 191ms/step - accuracy: 1.0000 - loss: 8.6510e-07 - val_accuracy: 1.0000 - val_loss: 1.4682e-06 - learning_rate: 3.9063e-06
# Epoch 57/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 1.0000 - loss: 8.6461e-07
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 299s 192ms/step - accuracy: 1.0000 - loss: 8.6441e-07 - val_accuracy: 1.0000 - val_loss: 1.3078e-06 - learning_rate: 3.9063e-06
# Epoch 58/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 300s 192ms/step - accuracy: 1.0000 - loss: 4.7976e-07 - val_accuracy: 1.0000 - val_loss: 1.5671e-06 - learning_rate: 1.9531e-06
# Epoch 59/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 298s 191ms/step - accuracy: 1.0000 - loss: 3.9120e-07 - val_accuracy: 1.0000 - val_loss: 1.4192e-06 - learning_rate: 1.9531e-06
# Epoch 60/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 302s 193ms/step - accuracy: 1.0000 - loss: 1.1948e-06 - val_accuracy: 1.0000 - val_loss: 1.3560e-06 - learning_rate: 1.9531e-06
# Epoch 61/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 298s 191ms/step - accuracy: 1.0000 - loss: 6.3527e-07 - val_accuracy: 1.0000 - val_loss: 1.4042e-06 - learning_rate: 1.9531e-06
# Epoch 62/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 2.5986e-07
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 296s 190ms/step - accuracy: 1.0000 - loss: 2.5986e-07 - val_accuracy: 1.0000 - val_loss: 1.5101e-06 - learning_rate: 1.9531e-06
# Epoch 63/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 299s 192ms/step - accuracy: 1.0000 - loss: 1.9564e-06 - val_accuracy: 1.0000 - val_loss: 1.3150e-06 - learning_rate: 1.0000e-06
# Epoch 64/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 301s 193ms/step - accuracy: 1.0000 - loss: 4.1189e-07 - val_accuracy: 1.0000 - val_loss: 1.3762e-06 - learning_rate: 1.0000e-06
# Epoch 65/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 298s 191ms/step - accuracy: 1.0000 - loss: 3.6390e-07 - val_accuracy: 1.0000 - val_loss: 1.2627e-06 - learning_rate: 1.0000e-06
# Epoch 66/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 297s 191ms/step - accuracy: 1.0000 - loss: 3.8660e-07 - val_accuracy: 1.0000 - val_loss: 1.3014e-06 - learning_rate: 1.0000e-06
# Epoch 67/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 295s 189ms/step - accuracy: 1.0000 - loss: 1.3701e-05 - val_accuracy: 1.0000 - val_loss: 1.3247e-06 - learning_rate: 1.0000e-06
# Epoch 68/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 298s 191ms/step - accuracy: 1.0000 - loss: 5.4593e-07 - val_accuracy: 1.0000 - val_loss: 1.4732e-06 - learning_rate: 1.0000e-06
# Epoch 69/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 303s 194ms/step - accuracy: 1.0000 - loss: 3.8502e-07 - val_accuracy: 1.0000 - val_loss: 1.4336e-06 - learning_rate: 1.0000e-06
# Epoch 70/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 297s 190ms/step - accuracy: 1.0000 - loss: 2.7936e-07 - val_accuracy: 1.0000 - val_loss: 1.4038e-06 - learning_rate: 1.0000e-06
# Epoch 71/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 305s 196ms/step - accuracy: 1.0000 - loss: 2.7995e-07 - val_accuracy: 1.0000 - val_loss: 1.3297e-06 - learning_rate: 1.0000e-06
# Epoch 72/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 317s 203ms/step - accuracy: 1.0000 - loss: 5.1987e-06 - val_accuracy: 1.0000 - val_loss: 1.4296e-06 - learning_rate: 1.0000e-06
# Epoch 73/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 318s 204ms/step - accuracy: 1.0000 - loss: 3.6251e-07 - val_accuracy: 1.0000 - val_loss: 1.4076e-06 - learning_rate: 1.0000e-06
# Epoch 74/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 316s 203ms/step - accuracy: 1.0000 - loss: 9.4544e-07 - val_accuracy: 1.0000 - val_loss: 1.3992e-06 - learning_rate: 1.0000e-06
# Epoch 75/200
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 317s 203ms/step - accuracy: 1.0000 - loss: 5.9879e-07 - val_accuracy: 1.0000 - val_loss: 1.2860e-06 - learning_rate: 1.0000e-06
# Epoch 75: early stopping
# Restoring model weights from the end of the best epoch: 65.
# [STEP 8] Training complete ✅
# ✅ Final model saved: p_eegformer-v1.keras
# ✅ Training log saved: ad_final_train_log.csv
# ✅ Normalization files saved: train_mean.pkl, train_std.pkl
# [STEP 9] Plotting training curves...
# [STEP 9] Plots generated ✅

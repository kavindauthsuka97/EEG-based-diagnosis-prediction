# %% [markdown]
# * list down all the folders

# %%
from pathlib import Path

base_path = Path(r"D:\Dermerzel\SomnasNest\Parkinson\Data")

folders = [p.name for p in base_path.iterdir() if p.is_dir()]

for folder in folders:
    print(folder)
# Out:
# sub-PD1001
# sub-PD1011
# sub-PD1021
# sub-PD1031
# sub-PD1041
# sub-PD1051
# sub-PD1061
# sub-PD1071
# sub-PD1081
# sub-PD1091
# sub-PD1101
# sub-PD1111
# sub-PD1121
# sub-PD1131
# sub-PD1141
# sub-PD1151
# sub-PD1161
# sub-PD1171
# sub-PD1181
# sub-PD1191
# sub-PD1201

# %% [markdown]
# * load sub-01 EEG data

# %%
pip install mne
# Out:
# Requirement already satisfied: mne in c:\users\hp\anaconda3\envs\dl\lib\site-packages (1.11.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from mne) (5.2.1)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.8 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from mne) (3.10.8)
# Requirement already satisfied: numpy<3,>=1.26 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from mne) (2.1.3)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from mne) (25.0)
# Requirement already satisfied: pooch>=1.5 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.11 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from mne) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from mne) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.8->mne) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.8->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.8->mne) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.8->mne) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.8->mne) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.8->mne) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from matplotlib>=3.8->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from pooch>=1.5->mne) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from pooch>=1.5->mne) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8->mne) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2026.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\envs\dl\lib\site-packages (from tqdm->mne) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mne
from pathlib import Path

# Path to subject folder
sub_path = Path(r"D:\Dermerzel\SomnasNest\Parkinson\Data\sub-PD1001")

# Find the .vhdr file
vhdr_file = list(sub_path.glob("*.vhdr"))[0]

# Load EEG data
raw = mne.io.read_raw_brainvision(vhdr_file, preload=True)

# Print basic info
print(raw)
# Out:
# Extracting parameters from D:\Dermerzel\SomnasNest\Parkinson\Data\sub-PD1001\sub-PD1001_ses-01_task-rest_eeg.vhdr...
# Setting channel info structure...
# C:\Users\HP\AppData\Local\Temp\ipykernel_20644\1674075929.py:11: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = mne.io.read_raw_brainvision(vhdr_file, preload=True)
# Reading 0 ... 140829  =      0.000 ...   281.658 secs...
# <RawBrainVision | sub-PD1001_ses-01_task-rest_eeg.eeg, 63 x 140830 (281.7 s), ~67.8 MiB, data loaded>

# %%
# Show channel names
print(raw.ch_names)
# Out:
# ['Fp1', 'Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'TP9', 'CP5', 'CP1', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'Fp2', 'AF7', 'AF3', 'AFz', 'F1', 'F5', 'FT7', 'FC3', 'C1', 'C5', 'TP7', 'CP3', 'P1', 'P5', 'PO7', 'PO3', 'POz', 'PO4', 'PO8', 'P6', 'P2', 'CPz', 'CP4', 'TP8', 'C6', 'C2', 'FC4', 'FT8', 'F6', 'AF8', 'AF4', 'F2', 'FCz']

# %% [markdown]
# * save postive class subjects as numpy array

# %%
# If needed: pip install mne numpy

from pathlib import Path  # for handling folder paths
import mne  # for loading BrainVision EEG data
import numpy as np  # for numerical operations

# ----------------------- CONFIG -----------------------
root_dir = Path(r"D:\Dermerzel\SomnasNest\Parkinson\Data")  # root dataset folder
exclude_channel = "FCz"  # channel to exclude
# ------------------------------------------------------

print(f"[INFO] Root directory: {root_dir}")  # print root directory

subfolders = [p for p in root_dir.iterdir() if p.is_dir()]  # get all subfolders
print(f"[INFO] Found {len(subfolders)} folders\n")  # print number of folders

min_length = None  # will store minimum number of samples found

for folder in subfolders:  # loop through each folder
    print("=" * 70)
    print(f"[INFO] Processing folder: {folder.name}")  # print folder name

    vhdr_files = list(folder.glob("*.vhdr"))  # find vhdr files

    if not vhdr_files:  # if no vhdr file found
        print("[WARN] No .vhdr file found. Skipping.")
        continue  # move to next folder

    vhdr_path = vhdr_files[0]  # usually one vhdr per folder
    print(f"[INFO] Loading file: {vhdr_path.name}")  # print file name

    try:
        raw = mne.io.read_raw_brainvision(
            str(vhdr_path),
            preload=True,
            verbose="ERROR"
        )  # load EEG data

        # Create lowercase mapping of channel names
        ch_map = {ch.lower(): ch for ch in raw.ch_names}

        # Remove FCz if present
        if exclude_channel.lower() in ch_map:
            raw.drop_channels([ch_map[exclude_channel.lower()]])
            print(f"[INFO] Dropped channel: {exclude_channel}")
        else:
            print(f"[INFO] Channel '{exclude_channel}' not found")

        data = raw.get_data()  # get EEG data (channels x samples)

        n_channels = data.shape[0]  # number of channels
        n_samples = data.shape[1]  # number of samples

        print(f"[INFO] EEG shape (channels x samples): {data.shape}")
        print(f"[INFO] Number of channels: {n_channels}")
        print(f"[INFO] Number of samples: {n_samples}")

        # Update minimum length
        if min_length is None or n_samples < min_length:
            min_length = n_samples
            print(f"[INFO] New minimum length found: {min_length}")

    except Exception as e:
        print("[ERROR] Failed to load EEG")
        print(f"[ERROR] {repr(e)}")

print("\n" + "=" * 70)
print(f"[RESULT] Minimum EEG array length (samples): {min_length}")
print("[INFO] Done.")
# Out:
# [INFO] Root directory: D:\Dermerzel\SomnasNest\Parkinson\Data
# [INFO] Found 22 folders
#
# ======================================================================
# [INFO] Processing folder: numpy_arrays
# [WARN] No .vhdr file found. Skipping.
# ======================================================================
# [INFO] Processing folder: sub-PD1001
# [INFO] Loading file: sub-PD1001_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 140830)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 140830
# [INFO] New minimum length found: 140830
# ======================================================================
# [INFO] Processing folder: sub-PD1011
# [INFO] Loading file: sub-PD1011_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 163020)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 163020
# ======================================================================
# [INFO] Processing folder: sub-PD1021
# [INFO] Loading file: sub-PD1021_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 126180)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 126180
# [INFO] New minimum length found: 126180
# ======================================================================
# [INFO] Processing folder: sub-PD1031
# [INFO] Loading file: sub-PD1031_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 131980)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 131980
# ======================================================================
# [INFO] Processing folder: sub-PD1041
# [INFO] Loading file: sub-PD1041_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 124770)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 124770
# [INFO] New minimum length found: 124770
# ======================================================================
# [INFO] Processing folder: sub-PD1051
# [INFO] Loading file: sub-PD1051_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 131030)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 131030
# ======================================================================
# [INFO] Processing folder: sub-PD1061
# [INFO] Loading file: sub-PD1061_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 119910)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 119910
# [INFO] New minimum length found: 119910
# ======================================================================
# [INFO] Processing folder: sub-PD1071
# [INFO] Loading file: sub-PD1071_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 117240)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 117240
# [INFO] New minimum length found: 117240
# ======================================================================
# [INFO] Processing folder: sub-PD1081
# [INFO] Loading file: sub-PD1081_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 124080)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 124080
# ======================================================================
# [INFO] Processing folder: sub-PD1091
# [INFO] Loading file: sub-PD1091_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 171350)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 171350
# ======================================================================
# [INFO] Processing folder: sub-PD1101
# [INFO] Loading file: sub-PD1101_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 78060)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 78060
# [INFO] New minimum length found: 78060
# ======================================================================
# [INFO] Processing folder: sub-PD1111
# [INFO] Loading file: sub-PD1111_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 60280)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 60280
# [INFO] New minimum length found: 60280
# ======================================================================
# [INFO] Processing folder: sub-PD1121
# [INFO] Loading file: sub-PD1121_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 61530)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 61530
# ======================================================================
# [INFO] Processing folder: sub-PD1131
# [INFO] Loading file: sub-PD1131_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 62800)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 62800
# ======================================================================
# [INFO] Processing folder: sub-PD1141
# [INFO] Loading file: sub-PD1141_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 60410)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 60410
# ======================================================================
# [INFO] Processing folder: sub-PD1151
# [INFO] Loading file: sub-PD1151_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 60830)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 60830
# ======================================================================
# [INFO] Processing folder: sub-PD1161
# [INFO] Loading file: sub-PD1161_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 92610)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 92610
# ======================================================================
# [INFO] Processing folder: sub-PD1171
# [INFO] Loading file: sub-PD1171_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 75780)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 75780
# ======================================================================
# [INFO] Processing folder: sub-PD1181
# [INFO] Loading file: sub-PD1181_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 93040)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 93040
# ======================================================================
# [INFO] Processing folder: sub-PD1191
# [INFO] Loading file: sub-PD1191_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 90590)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 90590
# ======================================================================
# [INFO] Processing folder: sub-PD1201
# [INFO] Loading file: sub-PD1201_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] EEG shape (channels x samples): (62, 79670)
# [INFO] Number of channels: 62
# [INFO] Number of samples: 79670
#
# ======================================================================
# [RESULT] Minimum EEG array length (samples): 60280
# [INFO] Done.

# %%
# If needed: pip install mne numpy

from pathlib import Path  # for file and folder handling
import numpy as np  # for numpy arrays
import mne  # for loading BrainVision EEG files

# ----------------------- CONFIG -----------------------
root_dir = Path(r"D:\Dermerzel\SomnasNest\Parkinson\Data")  # dataset root
exclude_channel = "FCz"  # channel to remove
timepoints = 60000  # number of timepoints to keep
output_file = root_dir / "parkinson_positive.npy"  # output file
# ------------------------------------------------------

print(f"[INFO] Root directory: {root_dir}")

subfolders = sorted([p for p in root_dir.iterdir() if p.is_dir()])  # list folders
print(f"[INFO] Found {len(subfolders)} folders")

all_samples = []  # will store EEG arrays from all folders

for folder in subfolders:
    print("\n" + "=" * 70)
    print(f"[INFO] Processing folder: {folder.name}")

    vhdr_files = list(folder.glob("*.vhdr"))  # find vhdr file

    if not vhdr_files:
        print("[WARN] No .vhdr file found. Skipping.")
        continue

    vhdr_path = vhdr_files[0]
    print(f"[INFO] Loading EEG: {vhdr_path.name}")

    try:
        raw = mne.io.read_raw_brainvision(
            str(vhdr_path),
            preload=True,
            verbose="ERROR"
        )  # load EEG data

        # Map channel names to lowercase for safe comparison
        ch_map = {ch.lower(): ch for ch in raw.ch_names}

        # Drop FCz if present
        if exclude_channel.lower() in ch_map:
            raw.drop_channels([ch_map[exclude_channel.lower()]])
            print(f"[INFO] Dropped channel: {exclude_channel}")
        else:
            print(f"[INFO] Channel '{exclude_channel}' not found")

        data = raw.get_data()  # shape: (channels, samples)
        print(f"[INFO] Raw data shape (channels x samples): {data.shape}")

        # Check if enough timepoints exist
        if data.shape[1] < timepoints:
            print(f"[WARN] Not enough timepoints ({data.shape[1]}). Skipping.")
            continue

        # Select last 60000 timepoints
        data = data[:, -timepoints:]  # (channels, 60000)
        print(f"[INFO] After slicing last {timepoints} timepoints: {data.shape}")

        # Transpose to (channels stay second dim later)
        data = data.astype(np.float32)  # ensure consistent dtype

        all_samples.append(data)  # add to list
        print(f"[INFO] Sample added. Current count: {len(all_samples)}")

    except Exception as e:
        print("[ERROR] Failed to process EEG")
        print(f"[ERROR] {repr(e)}")

print("\n" + "=" * 70)

# Stack into final numpy array
final_array = np.stack(all_samples, axis=0)  
# shape: (num_samples, num_channels, timepoints)

print(f"[RESULT] Final array shape: {final_array.shape}")

# Save final array
np.save(output_file, final_array)
print(f"[RESULT] Saved array to: {output_file}")

print("[INFO] Done.")
# Out:
# [INFO] Root directory: D:\Dermerzel\SomnasNest\Parkinson\Data
# [INFO] Found 22 folders
#
# ======================================================================
# [INFO] Processing folder: numpy_arrays
# [WARN] No .vhdr file found. Skipping.
#
# ======================================================================
# [INFO] Processing folder: sub-PD1001
# [INFO] Loading EEG: sub-PD1001_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 140830)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 1
#
# ======================================================================
# [INFO] Processing folder: sub-PD1011
# [INFO] Loading EEG: sub-PD1011_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 163020)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 2
#
# ======================================================================
# [INFO] Processing folder: sub-PD1021
# [INFO] Loading EEG: sub-PD1021_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 126180)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 3
#
# ======================================================================
# [INFO] Processing folder: sub-PD1031
# [INFO] Loading EEG: sub-PD1031_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 131980)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 4
#
# ======================================================================
# [INFO] Processing folder: sub-PD1041
# [INFO] Loading EEG: sub-PD1041_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 124770)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 5
#
# ======================================================================
# [INFO] Processing folder: sub-PD1051
# [INFO] Loading EEG: sub-PD1051_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 131030)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 6
#
# ======================================================================
# [INFO] Processing folder: sub-PD1061
# [INFO] Loading EEG: sub-PD1061_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 119910)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 7
#
# ======================================================================
# [INFO] Processing folder: sub-PD1071
# [INFO] Loading EEG: sub-PD1071_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 117240)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 8
#
# ======================================================================
# [INFO] Processing folder: sub-PD1081
# [INFO] Loading EEG: sub-PD1081_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 124080)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 9
#
# ======================================================================
# [INFO] Processing folder: sub-PD1091
# [INFO] Loading EEG: sub-PD1091_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 171350)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 10
#
# ======================================================================
# [INFO] Processing folder: sub-PD1101
# [INFO] Loading EEG: sub-PD1101_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 78060)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 11
#
# ======================================================================
# [INFO] Processing folder: sub-PD1111
# [INFO] Loading EEG: sub-PD1111_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 60280)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 12
#
# ======================================================================
# [INFO] Processing folder: sub-PD1121
# [INFO] Loading EEG: sub-PD1121_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 61530)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 13
#
# ======================================================================
# [INFO] Processing folder: sub-PD1131
# [INFO] Loading EEG: sub-PD1131_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 62800)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 14
#
# ======================================================================
# [INFO] Processing folder: sub-PD1141
# [INFO] Loading EEG: sub-PD1141_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 60410)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 15
#
# ======================================================================
# [INFO] Processing folder: sub-PD1151
# [INFO] Loading EEG: sub-PD1151_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 60830)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 16
#
# ======================================================================
# [INFO] Processing folder: sub-PD1161
# [INFO] Loading EEG: sub-PD1161_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 92610)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 17
#
# ======================================================================
# [INFO] Processing folder: sub-PD1171
# [INFO] Loading EEG: sub-PD1171_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 75780)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 18
#
# ======================================================================
# [INFO] Processing folder: sub-PD1181
# [INFO] Loading EEG: sub-PD1181_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 93040)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 19
#
# ======================================================================
# [INFO] Processing folder: sub-PD1191
# [INFO] Loading EEG: sub-PD1191_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 90590)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 20
#
# ======================================================================
# [INFO] Processing folder: sub-PD1201
# [INFO] Loading EEG: sub-PD1201_ses-01_task-rest_eeg.vhdr
# [INFO] Dropped channel: FCz
# [INFO] Raw data shape (channels x samples): (62, 79670)
# [INFO] After slicing last 60000 timepoints: (62, 60000)
# [INFO] Sample added. Current count: 21
#
# ======================================================================
# [RESULT] Final array shape: (21, 62, 60000)
# [RESULT] Saved array to: D:\Dermerzel\SomnasNest\Parkinson\Data\parkinson_positive.npy
# [INFO] Done.

# %% [markdown]
# * non-parkinson array

# %%
import mne
import numpy as np
from pathlib import Path

print("=== EEG Loading Started ===")

# --------------------------------------------------
# PATHS
# --------------------------------------------------
input_base_path = Path(r"D:\Dermerzel\SomnasNest\Alzheimer\Data")
output_path = Path(r"D:\Dermerzel\SomnasNest\Parkinson\Data\parkinson_negative.npy")

print(f"Input base path: {input_base_path}")
print(f"Output file: {output_path}")

TARGET_LENGTH = 60_000  # fixed number of time points

# --------------------------------------------------
# CHANNEL SELECTION (ORDER MATTERS)
# --------------------------------------------------
SELECTED_CHANNELS = [
    'Fp1', 'Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'TP9',
    'CP5', 'CP1', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10',
    'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8',
    'Fp2', 'AF7', 'AF3', 'AFz', 'F1', 'F5', 'FT7', 'FC3', 'C1', 'C5',
    'TP7', 'CP3', 'P1', 'P5', 'PO7', 'PO3', 'POz', 'PO4', 'PO8',
    'P6', 'P2', 'CPz', 'CP4', 'TP8', 'C6', 'C2', 'FC4', 'FT8',
    'F6', 'AF8', 'AF4', 'F2'
]

eeg_data_list = []
loaded_subjects = []

# --------------------------------------------------
# STEP 1: LOAD + SELECT CHANNELS + CROP
# --------------------------------------------------
for i in range(1, 32):
    sub_id = f"sub-{i:02d}"
    sub_path = input_base_path / sub_id

    print("\n----------------------------------")
    print(f"Processing {sub_id}")
    print(f"Looking in: {sub_path}")

    if not sub_path.exists():
        print(f"❌ Folder not found: {sub_path}")
        continue

    vhdr_files = list(sub_path.glob("*.vhdr"))
    print(f"Found {len(vhdr_files)} .vhdr file(s)")

    if not vhdr_files:
        print(f"⚠️ No .vhdr file found in {sub_id}, skipping.")
        continue

    vhdr_file = vhdr_files[0]
    print(f"Using file: {vhdr_file.name}")

    try:
        print("→ Loading EEG data...")
        raw = mne.io.read_raw_brainvision(vhdr_file, preload=True, verbose=False)

        print("→ Picking selected EEG channels...")
        raw.pick_channels(SELECTED_CHANNELS, ordered=True)

        print("→ Extracting NumPy array...")
        data = raw.get_data()  # shape: (channels, time)

        n_channels, n_times = data.shape
        print(f"✔ Shape after channel selection: {data.shape}")

        if n_times < TARGET_LENGTH:
            print(f"⚠️ Skipping {sub_id}: only {n_times} samples (< {TARGET_LENGTH})")
            continue

        # Keep FIRST 60,000 samples
        cropped = data[:, :TARGET_LENGTH].astype(np.float16)
        print(f"✔ Cropped shape: {cropped.shape}")

        eeg_data_list.append(cropped)
        loaded_subjects.append(sub_id)

        print(f"✔ {sub_id} successfully processed.")

    except Exception as e:
        print(f"❌ Error loading {sub_id}: {e}")
        continue

# --------------------------------------------------
# STEP 2: STACK + SAVE
# --------------------------------------------------
print("\n==================================")
print("EEG Loading Finished")
print(f"Total subjects loaded: {len(eeg_data_list)}")
print(f"Subjects: {loaded_subjects}")

print("\n→ Stacking all subjects into one NumPy array...")

try:
    parkinson_negative = np.stack(eeg_data_list, axis=0)
    print("✔ Stacking successful.")
    print("Final shape:", parkinson_negative.shape)
    print("Data type:", parkinson_negative.dtype)

    print(f"→ Saving to {output_path}")
    np.save(output_path, parkinson_negative)
    print("✔ File saved successfully.")

except MemoryError as e:
    print("❌ Memory error during stacking!")
    print(e)

print("\n=== PROCESS COMPLETED ===")
# Out:
# === EEG Loading Started ===
# Input base path: D:\Dermerzel\SomnasNest\Alzheimer\Data
# Output file: D:\Dermerzel\SomnasNest\Parkinson\Data\parkinson_negative.npy
#
# ----------------------------------
# Processing sub-01
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-01
# Found 1 .vhdr file(s)
# Using file: sub-01_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 661520)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-01 successfully processed.
#
# ----------------------------------
# Processing sub-02
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-02
# Found 1 .vhdr file(s)
# Using file: sub-02_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 637720)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-02 successfully processed.
#
# ----------------------------------
# Processing sub-03
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-03
# Found 1 .vhdr file(s)
# Using file: sub-03_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 670760)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-03 successfully processed.
#
# ----------------------------------
# Processing sub-04
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-04
# Found 1 .vhdr file(s)
# Using file: sub-04_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 704100)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-04 successfully processed.
#
# ----------------------------------
# Processing sub-05
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-05
# Found 1 .vhdr file(s)
# Using file: sub-05_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 644860)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-05 successfully processed.
#
# ----------------------------------
# Processing sub-06
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-06
# Found 1 .vhdr file(s)
# Using file: sub-06_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 632820)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-06 successfully processed.
#
# ----------------------------------
# Processing sub-07
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-07
# Found 1 .vhdr file(s)
# Using file: sub-07_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 734580)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-07 successfully processed.
#
# ----------------------------------
# Processing sub-08
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-08
# Found 1 .vhdr file(s)
# Using file: sub-08_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 648280)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-08 successfully processed.
#
# ----------------------------------
# Processing sub-09
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-09
# Found 1 .vhdr file(s)
# Using file: sub-09_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 693920)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-09 successfully processed.
#
# ----------------------------------
# Processing sub-10
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-10
# Found 1 .vhdr file(s)
# Using file: sub-10_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 640160)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-10 successfully processed.
#
# ----------------------------------
# Processing sub-11
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-11
# Found 1 .vhdr file(s)
# Using file: sub-11_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 647640)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-11 successfully processed.
#
# ----------------------------------
# Processing sub-12
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-12
# Found 1 .vhdr file(s)
# Using file: sub-12_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 656420)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-12 successfully processed.
#
# ----------------------------------
# Processing sub-13
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-13
# Found 1 .vhdr file(s)
# Using file: sub-13_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 636960)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-13 successfully processed.
#
# ----------------------------------
# Processing sub-14
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-14
# Found 1 .vhdr file(s)
# Using file: sub-14_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 674900)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-14 successfully processed.
#
# ----------------------------------
# Processing sub-15
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-15
# Found 1 .vhdr file(s)
# Using file: sub-15_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 646220)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-15 successfully processed.
#
# ----------------------------------
# Processing sub-16
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-16
# Found 1 .vhdr file(s)
# Using file: sub-16_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 629500)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-16 successfully processed.
#
# ----------------------------------
# Processing sub-17
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-17
# Found 1 .vhdr file(s)
# Using file: sub-17_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 669120)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-17 successfully processed.
#
# ----------------------------------
# Processing sub-18
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-18
# Found 1 .vhdr file(s)
# Using file: sub-18_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 639620)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-18 successfully processed.
#
# ----------------------------------
# Processing sub-19
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-19
# Found 1 .vhdr file(s)
# Using file: sub-19_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 617740)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-19 successfully processed.
#
# ----------------------------------
# Processing sub-20
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-20
# Found 1 .vhdr file(s)
# Using file: sub-20_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 626480)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-20 successfully processed.
#
# ----------------------------------
# Processing sub-21
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-21
# Found 1 .vhdr file(s)
# Using file: sub-21_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 756180)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-21 successfully processed.
#
# ----------------------------------
# Processing sub-22
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-22
# Found 1 .vhdr file(s)
# Using file: sub-22_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 640960)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-22 successfully processed.
#
# ----------------------------------
# Processing sub-23
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-23
# Found 1 .vhdr file(s)
# Using file: sub-23_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 635740)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-23 successfully processed.
#
# ----------------------------------
# Processing sub-24
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-24
# Found 1 .vhdr file(s)
# Using file: sub-24_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 660520)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-24 successfully processed.
#
# ----------------------------------
# Processing sub-25
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-25
# Found 1 .vhdr file(s)
# Using file: sub-25_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 625600)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-25 successfully processed.
#
# ----------------------------------
# Processing sub-26
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-26
# Found 1 .vhdr file(s)
# Using file: sub-26_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 698540)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-26 successfully processed.
#
# ----------------------------------
# Processing sub-27
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-27
# Found 1 .vhdr file(s)
# Using file: sub-27_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 644200)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-27 successfully processed.
#
# ----------------------------------
# Processing sub-28
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-28
# Found 1 .vhdr file(s)
# Using file: sub-28_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 689240)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-28 successfully processed.
#
# ----------------------------------
# Processing sub-29
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-29
# Found 1 .vhdr file(s)
# Using file: sub-29_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 664080)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-29 successfully processed.
#
# ----------------------------------
# Processing sub-30
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-30
# Found 1 .vhdr file(s)
# Using file: sub-30_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 628840)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-30 successfully processed.
#
# ----------------------------------
# Processing sub-31
# Looking in: D:\Dermerzel\SomnasNest\Alzheimer\Data\sub-31
# Found 1 .vhdr file(s)
# Using file: sub-31_task-rest_eeg.vhdr
# → Loading EEG data...
# → Picking selected EEG channels...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# → Extracting NumPy array...
# ✔ Shape after channel selection: (62, 646800)
# ✔ Cropped shape: (62, 60000)
# ✔ sub-31 successfully processed.
#
# ==================================
# EEG Loading Finished
# Total subjects loaded: 31
# Subjects: ['sub-01', 'sub-02', 'sub-03', 'sub-04', 'sub-05', 'sub-06', 'sub-07', 'sub-08', 'sub-09', 'sub-10', 'sub-11', 'sub-12', 'sub-13', 'sub-14', 'sub-15', 'sub-16', 'sub-17', 'sub-18', 'sub-19', 'sub-20', 'sub-21', 'sub-22', 'sub-23', 'sub-24', 'sub-25', 'sub-26', 'sub-27', 'sub-28', 'sub-29', 'sub-30', 'sub-31']
#
# → Stacking all subjects into one NumPy array...
# ✔ Stacking successful.
# Final shape: (31, 62, 60000)
# Data type: float16
# → Saving to D:\Dermerzel\SomnasNest\Parkinson\Data\parkinson_negative.npy
# ✔ File saved successfully.
#
# === PROCESS COMPLETED ===
